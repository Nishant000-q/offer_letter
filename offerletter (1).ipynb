# %% [markdown]
# Offer of Employment
#
# Noida
#
# Dear Roopesh,
#
# Subject: Offer of Employment for the position of Python
# We are delighted to extend this formal offer of employment to you for the position of
# Python at our organization. Based on your qualifications and the skills you demonstrated
# during the recruitment process, we are confident that you will be a valuable addition to our
# team.
#
# As discussed, your expected date of joining is 12-2-3020. Your total compensation package
# will be 4000000, which includes all salary components as per the company’s policy. Further
# details regarding your compensation will be provided in your employment contract.
#
# We expect you to bring your best efforts to help the company achieve its goals, and we are
# committed to supporting your professional growth during your time with us.
#
# Please confirm your acceptance of this offer by sending an email to rkt@gmail.com at your
# earliest convenience. Should you have any queries regarding this offer, feel free to reach out
# to us.
#
# We look forward to having you onboard and are excited about the great things we can
# accomplish together.
# Sincerely,
# Sunil Kumar
# HR Manager

# %%
city_name = input("Enter the city name. ")
emp_name = input("Enter the Employee name. ")
position = input("Enter the Position name. ")
join_date = input("Enter the joining date . ")
emp_package = input("Enter the Employee package . ")
emp_email = input("Enter the Employee email. ")
manager_name = input("Enter the HR_name.")
offer_letter1 = f"""
    Offer of Employment

{city_name}

Dear {emp_name},

Subject: Offer of Employment for the position of {position}
We are delighted to extend this formal offer of employment to you for the position of
Python at our organization. Based on your qualifications and the skills you demonstrated
during the recruitment process, we are confident that you will be a valuable addition to our
team.

As discussed, your expected date of joining is {join_date}. Your total compensation package
will be {emp_package}, which includes all salary components as per the company’s policy. Further
details regarding your compensation will be provided in your employment contract.

We expect you to bring your best efforts to help the company achieve its goals, and we are
committed to supporting your professional growth during your time with us.
Please confirm your acceptance of this offer by sending an email to {emp_email} at your
earliest convenience. Should you have any queries regarding this offer, feel free to reach out
to us.

We look forward to having you onboard and are excited about the great thijjjjngs we can
accomplish together.
Sincerely,
{manager_name}
HR Manager """
print(offer_letter1)
# Out:
# Enter the city name.  Delhi
# Enter the Employee name.  Nishant Chauhan
# Enter the Position name.  Java
# Enter the joining date .  10-3-2026
# Enter the Employee package .  40000000
# Enter the Employee email.  nishantchauhano890@gmail.com
